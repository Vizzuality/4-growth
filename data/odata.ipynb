# %%
import pandas as pd
import requests
from datetime import datetime
import json

# define function to transform the data received from the OData call into
# a pandas DataFrame for ease of use
def get_request_to_dataframe(response_content):
    # loads the bytes received from the GET request into JSON format
    content = json.loads(response_content.content)

    # extracts the data from the previous content variable
    data = content['value']

    # the appropriate column names are extracted from the original DataFrame
    # add some error handling for if there is no data
    columns = list(data[0].keys())

    # extracts the values from the key-value pairs of the dictionaries
    # in the input dataframe
    row_values = [elem.values() for elem in data]

    # all values per row are added as lists to a list
    unpacked_row_values = [list(item)[0:len(columns)] for item in row_values]

    # the list of lists of the previous step is converted to a DataFrame

    final_df = pd.DataFrame(unpacked_row_values)


    # column names are assigned to the DataFrame
    final_df.columns = columns

    # length check of rows. If the length of (a) row(s) exceeds the amount of
    # columns in the data. An error message is thrown identifying the number
    # and location of the problematic rows
    counter = 0
    row_index = []

    for i, elem in enumerate(unpacked_row_values):
        if len(elem) > len(columns):
            row_index.append(i)
            counter += 1

    if counter > 0:
        print(f'{counter} rows in the dataframe have a length greater than',
              ' the number of identified columns.', 'The index positions ',
              f'are: {row_index}')

    # returns final dataframe to caller
    return final_df, unpacked_row_values, data


# set the appropriate URL, change this when you want to query different models or entities. Or if
# you want to change the query result set
url = 'https://dataservices.wecr.wur.nl/odata/public/UNComtrade/Reporter?$select=ID,Name'

# set some date and time variables
now = datetime.now()

dt_string = now.strftime('%Y.%m.%d %H:%M:%S')

d_string = now.strftime('%Y.%m.%d')

t_string = now.strftime('%H:%M:%S')

# send a GET request to the OData API endpoint
response = requests.get(url)

# identify to the user if the GET request was succesful
if response.status_code == 200:
    print(f'GET request succeeded at {t_string}')
else:
    print('Failed: ', response.status_code)

# use the get_request_to_dataframe function to parse the GET request
parsed_df, unpacked_row_values, data = get_request_to_dataframe(response)
# Out:
# GET request succeeded at 14:31:32

# %%
parsed_df
# Out:
#          ID                          Name
# 0      1312                     Luxemburg
# 1      1321                         Malta
# 2     37893                        Soedan
# 3     37905                       Andorra
# 4     37906  Verenigde Arabische Emiraten
# ..      ...                           ...
# 198   38142                       Vietnam
# 199   38152                        Servië
# 200  366805                         Libya
# 201  366814         Serbia and Montenegro
# 202  366817                Sudan (former)
#
# [203 rows x 2 columns]

# %%
print(type(unpacked_row_values))
# Out:
# <class 'list'>

# %%
data
# Out:
# [{'ID': 1312, 'Name': 'Luxemburg'},
#  {'ID': 1321, 'Name': 'Malta'},
#  {'ID': 37893, 'Name': 'Soedan'},
#  {'ID': 37905, 'Name': 'Andorra'},
#  {'ID': 37906, 'Name': 'Verenigde Arabische Emiraten'},
#  {'ID': 37907, 'Name': 'Afghanistan'},
#  {'ID': 37908, 'Name': 'Antigua en Barbuda'},
#  {'ID': 37909, 'Name': 'Anguilla'},
#  {'ID': 37912, 'Name': 'Netherlands Antilles'},
#  {'ID': 37913, 'Name': 'Angola'},
#  {'ID': 37919, 'Name': 'Aruba'},
#  {'ID': 37920, 'Name': 'Azerbeidzjan'},
#  {'ID': 37922, 'Name': 'Barbados'},
#  {'ID': 37923, 'Name': 'Bangladesh'},
#  {'ID': 37925, 'Name': 'Burkina Faso'},
#  {'ID': 37926, 'Name': 'Bulgarije'},
#  {'ID': 37927, 'Name': 'Bahrein'},
#  {'ID': 37928, 'Name': 'Burundi'},
#  {'ID': 37929, 'Name': 'Benin'},
#  {'ID': 37930, 'Name': 'Bermuda'},
#  {'ID': 37931, 'Name': 'Brunei Darussalam'},
#  {'ID': 37932, 'Name': 'Bolivia'},
#  {'ID': 37934, 'Name': 'Bahamas'},
#  {'ID': 37935, 'Name': 'Bhutan'},
#  {'ID': 37937, 'Name': 'Botswana'},
#  {'ID': 37938, 'Name': 'Wit-Rusland'},
#  {'ID': 37939, 'Name': 'Belize'},
#  {'ID': 37940, 'Name': 'Canada'},
#  {'ID': 37942, 'Name': 'Democratic Republic of the Congo'},
#  {'ID': 37943, 'Name': 'Centraal Afrikaanse Republiek'},
#  {'ID': 37944, 'Name': 'Congo'},
#  {'ID': 37945, 'Name': 'Zwitserland'},
#  {'ID': 37946, 'Name': 'Ivoorkust'},
#  {'ID': 37947, 'Name': 'Cookeilanden'},
#  {'ID': 37948, 'Name': 'Chili'},
#  {'ID': 37949, 'Name': 'Kameroen'},
#  {'ID': 37950, 'Name': 'China'},
#  {'ID': 37951, 'Name': 'Colombia'},
#  {'ID': 37952, 'Name': 'Costa Rica'},
#  {'ID': 37953, 'Name': 'Cuba'},
#  {'ID': 37954, 'Name': 'Cabo Verde'},
#  {'ID': 37956, 'Name': 'Cyprus'},
#  {'ID': 37958, 'Name': 'Duitsland'},
#  {'ID': 37959, 'Name': 'Djibouti'},
#  {'ID': 37961, 'Name': 'Dominica'},
#  {'ID': 37962, 'Name': 'Dominicaanse Republiek'},
#  {'ID': 37963, 'Name': 'Algerije'},
#  {'ID': 37964, 'Name': 'Ecuador'},
#  {'ID': 37965, 'Name': 'Estland'},
#  {'ID': 37967, 'Name': 'Eritrea'},
#  {'ID': 37968, 'Name': 'Spanje'},
#  {'ID': 37971, 'Name': 'Finland'},
#  {'ID': 37972, 'Name': 'Fiji'},
#  {'ID': 37976, 'Name': 'Frankrijk'},
#  {'ID': 37977, 'Name': 'Gabon'},
#  {'ID': 37979, 'Name': 'Grenada'},
#  {'ID': 37982, 'Name': 'Ghana'},
#  {'ID': 37984, 'Name': 'Groenland'},
#  {'ID': 37985, 'Name': 'Gambia'},
#  {'ID': 37986, 'Name': 'Guinea'},
#  {'ID': 37989, 'Name': 'Griekenland'},
#  {'ID': 37991, 'Name': 'Guatemala'},
#  {'ID': 37993, 'Name': 'Guinee-Bissau'},
#  {'ID': 37994, 'Name': 'Guyana'},
#  {'ID': 37995, 'Name': 'Hong Kong'},
#  {'ID': 37997, 'Name': 'Honduras'},
#  {'ID': 38000, 'Name': 'Hongarije'},
#  {'ID': 38002, 'Name': 'Ierland'},
#  {'ID': 38004, 'Name': 'India'},
#  {'ID': 38006, 'Name': 'Irak'},
#  {'ID': 38007, 'Name': 'Iran'},
#  {'ID': 38008, 'Name': 'IJsland'},
#  {'ID': 38010, 'Name': 'Jamaica'},
#  {'ID': 38012, 'Name': 'Japan'},
#  {'ID': 38013, 'Name': 'Kenia'},
#  {'ID': 38015, 'Name': 'Cambodja'},
#  {'ID': 38016, 'Name': 'Kiribati'},
#  {'ID': 38017, 'Name': 'Comoren'},
#  {'ID': 38018, 'Name': 'Saint Kitts en Nevis'},
#  {'ID': 38021, 'Name': 'Koeweit'},
#  {'ID': 38022, 'Name': 'Kaaiman Eilanden'},
#  {'ID': 38023, 'Name': 'Kazachstan'},
#  {'ID': 38024, 'Name': 'Lao Democratische Volksrepubliek'},
#  {'ID': 38025, 'Name': 'Libanon'},
#  {'ID': 38026, 'Name': 'Sint Lucia'},
#  {'ID': 38028, 'Name': 'Sri Lanka'},
#  {'ID': 38030, 'Name': 'Lesotho'},
#  {'ID': 38031, 'Name': 'Litouwen'},
#  {'ID': 38035, 'Name': 'Marokko'},
#  {'ID': 38038, 'Name': 'Madagascar'},
#  {'ID': 38041, 'Name': 'Mali'},
#  {'ID': 38042, 'Name': 'Myanmar'},
#  {'ID': 38044, 'Name': 'Macao'},
#  {'ID': 38048, 'Name': 'Montserrat'},
#  {'ID': 38050, 'Name': 'Mauritius'},
#  {'ID': 38051, 'Name': 'Maldiven'},
#  {'ID': 38052, 'Name': 'Malawi'},
#  {'ID': 38053, 'Name': 'Mexico'},
#  {'ID': 38055, 'Name': 'Mozambique'},
#  {'ID': 38060, 'Name': 'Nigeria'},
#  {'ID': 38061, 'Name': 'Nicaragua'},
#  {'ID': 38063, 'Name': 'Noorwegen'},
#  {'ID': 38064, 'Name': 'Nepal'},
#  {'ID': 38067, 'Name': 'Nieuw-Zeeland'},
#  {'ID': 38068, 'Name': 'Oman'},
#  {'ID': 38069, 'Name': 'Panama'},
#  {'ID': 38070, 'Name': 'Peru'},
#  {'ID': 38072, 'Name': 'Papoea-Nieuw-Guinea'},
#  {'ID': 38073, 'Name': 'Filippijnen'},
#  {'ID': 38074, 'Name': 'Pakistan'},
#  {'ID': 38075, 'Name': 'Polen'},
#  {'ID': 38079, 'Name': 'Palestijnse staat'},
#  {'ID': 38080, 'Name': 'Portugal'},
#  {'ID': 38081, 'Name': 'Palau'},
#  {'ID': 38082, 'Name': 'Paraguay'},
#  {'ID': 38083, 'Name': 'Qatar'},
#  {'ID': 38095, 'Name': 'Rusland'},
#  {'ID': 38096, 'Name': 'Rwanda'},
#  {'ID': 38098, 'Name': 'Solomon eilanden'},
#  {'ID': 38099, 'Name': 'Seychellen'},
#  {'ID': 38101, 'Name': 'Zweden'},
#  {'ID': 38102, 'Name': 'Singapore'},
#  {'ID': 38105, 'Name': 'Slowakije'},
#  {'ID': 38106, 'Name': 'Sierra Leone'},
#  {'ID': 38108, 'Name': 'Senegal'},
#  {'ID': 38110, 'Name': 'Suriname'},
#  {'ID': 38111, 'Name': 'Sao Tome en Principe'},
#  {'ID': 38112, 'Name': 'El Salvador'},
#  {'ID': 38113, 'Name': 'Syrische Arabische Republiek'},
#  {'ID': 38114, 'Name': 'Swaziland'},
#  {'ID': 38115, 'Name': 'Turks- en Caicoseilanden'},
#  {'ID': 38118, 'Name': 'Togo'},
#  {'ID': 38119, 'Name': 'Thailand'},
#  {'ID': 38120, 'Name': 'Tadzjikistan'},
#  {'ID': 38122, 'Name': 'Oost-Timor'},
#  {'ID': 38123, 'Name': 'Turkmenistan'},
#  {'ID': 38126, 'Name': 'Turkije'},
#  {'ID': 38127, 'Name': 'Trinidad en Tobago'},
#  {'ID': 38128, 'Name': 'Tuvalu'},
#  {'ID': 38132, 'Name': 'Oeganda'},
#  {'ID': 38134, 'Name': 'Verenigde Staten'},
#  {'ID': 38135, 'Name': 'Uruguay'},
#  {'ID': 38136, 'Name': 'Oezbekistan'},
#  {'ID': 38138, 'Name': 'Saint Vincent en de Grenadines'},
#  {'ID': 38139, 'Name': 'Venezuela'},
#  {'ID': 38143, 'Name': 'Vanuatu'},
#  {'ID': 38144, 'Name': 'Wallis- en Futuna-eilanden'},
#  {'ID': 38145, 'Name': 'Samoa'},
#  {'ID': 38154, 'Name': 'Jemen'},
#  {'ID': 38155, 'Name': 'Mayotte'},
#  {'ID': 38156, 'Name': 'Zuid-Afrika'},
#  {'ID': 38157, 'Name': 'Zambia'},
#  {'ID': 38158, 'Name': 'Zimbabwe'},
#  {'ID': 122860, 'Name': 'Overig Azië, n.e.g.'},
#  {'ID': -1, 'Name': 'Onbekend'},
#  {'ID': 0, 'Name': 'Niet van toepassing'},
#  {'ID': 37910, 'Name': 'Albanië'},
#  {'ID': 37911, 'Name': 'Armenië'},
#  {'ID': 37915, 'Name': 'Argentinië'},
#  {'ID': 37917, 'Name': 'Oostenrijk'},
#  {'ID': 37918, 'Name': 'Australië'},
#  {'ID': 37921, 'Name': 'Bosnië-Herzegovina'},
#  {'ID': 37924, 'Name': 'België'},
#  {'ID': 37933, 'Name': 'Brazilië'},
#  {'ID': 37957, 'Name': 'Tsjechië'},
#  {'ID': 37960, 'Name': 'Denemarken'},
#  {'ID': 37966, 'Name': 'Egypte'},
#  {'ID': 37969, 'Name': 'Ethiopië'},
#  {'ID': 37974, 'Name': 'Micronesië, Federale Staten van'},
#  {'ID': 37975, 'Name': 'Faeröer'},
#  {'ID': 37978, 'Name': 'Verenigd Koninkrijk'},
#  {'ID': 37980, 'Name': 'Georgië'},
#  {'ID': 37998, 'Name': 'Kroatië'},
#  {'ID': 38001, 'Name': 'Indonesië'},
#  {'ID': 38003, 'Name': 'Israël'},
#  {'ID': 38009, 'Name': 'Italië'},
#  {'ID': 38011, 'Name': 'Jordanië'},
#  {'ID': 38014, 'Name': 'Kirgizië'},
#  {'ID': 38020, 'Name': 'Zuid-Korea'},
#  {'ID': 38033, 'Name': 'Letland'},
#  {'ID': 38036, 'Name': 'Moldavië'},
#  {'ID': 38037, 'Name': 'Montenegro'},
#  {'ID': 38040, 'Name': 'Noord-Macedonie'},
#  {'ID': 38043, 'Name': 'Mongolië'},
#  {'ID': 38047, 'Name': 'Mauritanië'},
#  {'ID': 38054, 'Name': 'Maleisië'},
#  {'ID': 38056, 'Name': 'Namibië'},
#  {'ID': 38057, 'Name': 'Nieuw-Caledonië'},
#  {'ID': 38058, 'Name': 'Niger'},
#  {'ID': 38062, 'Name': 'Nederland'},
#  {'ID': 38071, 'Name': 'Frans-Polynesië'},
#  {'ID': 38094, 'Name': 'Roemenië'},
#  {'ID': 38097, 'Name': 'Saoedi-Arabië'},
#  {'ID': 38104, 'Name': 'Slovenië'},
#  {'ID': 38124, 'Name': 'Tunesië'},
#  {'ID': 38125, 'Name': 'Tonga'},
#  {'ID': 38130, 'Name': 'Tanzania'},
#  {'ID': 38131, 'Name': 'Oekraïne'},
#  {'ID': 38142, 'Name': 'Vietnam'},
#  {'ID': 38152, 'Name': 'Servië'},
#  {'ID': 366805, 'Name': 'Libya'},
#  {'ID': 366814, 'Name': 'Serbia and Montenegro'},
#  {'ID': 366817, 'Name': 'Sudan (former)'}]

# %%
response = requests.get(url)
# Out:
# <Response [200]>

# %%
type(response)
print(response.content)
# Out:
# b'{"@odata.context":"https://dataservices.wecr.wur.nl/odata/public/UNComtrade/$metadata#Reporter","value":[{"ID":1312,"Name":"Luxemburg"},{"ID":1321,"Name":"Malta"},{"ID":37893,"Name":"Soedan"},{"ID":37905,"Name":"Andorra"},{"ID":37906,"Name":"Verenigde Arabische Emiraten"},{"ID":37907,"Name":"Afghanistan"},{"ID":37908,"Name":"Antigua en Barbuda"},{"ID":37909,"Name":"Anguilla"},{"ID":37912,"Name":"Netherlands Antilles"},{"ID":37913,"Name":"Angola"},{"ID":37919,"Name":"Aruba"},{"ID":37920,"Name":"Azerbeidzjan"},{"ID":37922,"Name":"Barbados"},{"ID":37923,"Name":"Bangladesh"},{"ID":37925,"Name":"Burkina Faso"},{"ID":37926,"Name":"Bulgarije"},{"ID":37927,"Name":"Bahrein"},{"ID":37928,"Name":"Burundi"},{"ID":37929,"Name":"Benin"},{"ID":37930,"Name":"Bermuda"},{"ID":37931,"Name":"Brunei Darussalam"},{"ID":37932,"Name":"Bolivia"},{"ID":37934,"Name":"Bahamas"},{"ID":37935,"Name":"Bhutan"},{"ID":37937,"Name":"Botswana"},{"ID":37938,"Name":"Wit-Rusland"},{"ID":37939,"Name":"Belize"},{"ID":37940,"Name":"Canada"},{"ID":37942,"Name":"Democratic Republic of the Congo"},{"ID":37943,"Name":"Centraal Afrikaanse Republiek"},{"ID":37944,"Name":"Congo"},{"ID":37945,"Name":"Zwitserland"},{"ID":37946,"Name":"Ivoorkust"},{"ID":37947,"Name":"Cookeilanden"},{"ID":37948,"Name":"Chili"},{"ID":37949,"Name":"Kameroen"},{"ID":37950,"Name":"China"},{"ID":37951,"Name":"Colombia"},{"ID":37952,"Name":"Costa Rica"},{"ID":37953,"Name":"Cuba"},{"ID":37954,"Name":"Cabo Verde"},{"ID":37956,"Name":"Cyprus"},{"ID":37958,"Name":"Duitsland"},{"ID":37959,"Name":"Djibouti"},{"ID":37961,"Name":"Dominica"},{"ID":37962,"Name":"Dominicaanse Republiek"},{"ID":37963,"Name":"Algerije"},{"ID":37964,"Name":"Ecuador"},{"ID":37965,"Name":"Estland"},{"ID":37967,"Name":"Eritrea"},{"ID":37968,"Name":"Spanje"},{"ID":37971,"Name":"Finland"},{"ID":37972,"Name":"Fiji"},{"ID":37976,"Name":"Frankrijk"},{"ID":37977,"Name":"Gabon"},{"ID":37979,"Name":"Grenada"},{"ID":37982,"Name":"Ghana"},{"ID":37984,"Name":"Groenland"},{"ID":37985,"Name":"Gambia"},{"ID":37986,"Name":"Guinea"},{"ID":37989,"Name":"Griekenland"},{"ID":37991,"Name":"Guatemala"},{"ID":37993,"Name":"Guinee-Bissau"},{"ID":37994,"Name":"Guyana"},{"ID":37995,"Name":"Hong Kong"},{"ID":37997,"Name":"Honduras"},{"ID":38000,"Name":"Hongarije"},{"ID":38002,"Name":"Ierland"},{"ID":38004,"Name":"India"},{"ID":38006,"Name":"Irak"},{"ID":38007,"Name":"Iran"},{"ID":38008,"Name":"IJsland"},{"ID":38010,"Name":"Jamaica"},{"ID":38012,"Name":"Japan"},{"ID":38013,"Name":"Kenia"},{"ID":38015,"Name":"Cambodja"},{"ID":38016,"Name":"Kiribati"},{"ID":38017,"Name":"Comoren"},{"ID":38018,"Name":"Saint Kitts en Nevis"},{"ID":38021,"Name":"Koeweit"},{"ID":38022,"Name":"Kaaiman Eilanden"},{"ID":38023,"Name":"Kazachstan"},{"ID":38024,"Name":"Lao Democratische Volksrepubliek"},{"ID":38025,"Name":"Libanon"},{"ID":38026,"Name":"Sint Lucia"},{"ID":38028,"Name":"Sri Lanka"},{"ID":38030,"Name":"Lesotho"},{"ID":38031,"Name":"Litouwen"},{"ID":38035,"Name":"Marokko"},{"ID":38038,"Name":"Madagascar"},{"ID":38041,"Name":"Mali"},{"ID":38042,"Name":"Myanmar"},{"ID":38044,"Name":"Macao"},{"ID":38048,"Name":"Montserrat"},{"ID":38050,"Name":"Mauritius"},{"ID":38051,"Name":"Maldiven"},{"ID":38052,"Name":"Malawi"},{"ID":38053,"Name":"Mexico"},{"ID":38055,"Name":"Mozambique"},{"ID":38060,"Name":"Nigeria"},{"ID":38061,"Name":"Nicaragua"},{"ID":38063,"Name":"Noorwegen"},{"ID":38064,"Name":"Nepal"},{"ID":38067,"Name":"Nieuw-Zeeland"},{"ID":38068,"Name":"Oman"},{"ID":38069,"Name":"Panama"},{"ID":38070,"Name":"Peru"},{"ID":38072,"Name":"Papoea-Nieuw-Guinea"},{"ID":38073,"Name":"Filippijnen"},{"ID":38074,"Name":"Pakistan"},{"ID":38075,"Name":"Polen"},{"ID":38079,"Name":"Palestijnse staat"},{"ID":38080,"Name":"Portugal"},{"ID":38081,"Name":"Palau"},{"ID":38082,"Name":"Paraguay"},{"ID":38083,"Name":"Qatar"},{"ID":38095,"Name":"Rusland"},{"ID":38096,"Name":"Rwanda"},{"ID":38098,"Name":"Solomon eilanden"},{"ID":38099,"Name":"Seychellen"},{"ID":38101,"Name":"Zweden"},{"ID":38102,"Name":"Si ...
